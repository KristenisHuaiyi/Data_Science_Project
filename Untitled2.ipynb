# %%
#load packages
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
install.packages("kknn")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.2     ✔ rsample      1.1.1
# ✔ dials        1.1.0     ✔ tune         1.0.1
# ✔ infer        1.0.4     ✔ workflows    1.1.2
# ✔ modeldata    1.0.1     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.3     ✔ yardstick    1.1.0
# ✔ recipes      1.0.4
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Search for functions across packages at https://www.tidymodels.org/find/
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
#use read_csv to load the data into R
data <- read_csv("data/heart_failure_clinical_records_dataset.csv.xls")
data
# Out:
# Rows: 299 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (13): age, anaemia, creatinine_phosphokinase, diabetes, ejection_fractio...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     age anaemia creatinine_phosphokinase diabetes ejection_fraction
# 1   75  0        582                     0        20
# 2   55  0       7861                     0        38
# 3   65  0        146                     0        20
# ⋮   ⋮   ⋮       ⋮                        ⋮        ⋮
# 297 45  0       2060                     1        60
# 298 45  0       2413                     0        38
# 299 50  0        196                     0        45
#     high_blood_pressure platelets serum_creatinine serum_sodium sex smoking
# 1   1                   265000    1.9              130          1   0
# 2   0                   263358    1.1              136          1   0
# 3   0                   162000    1.3              129          1   1
# ⋮   ⋮                   ⋮         ⋮                ⋮            ⋮   ⋮
# 297 0                   742000    0.8              138          0   0
# 298 0                   140000    1.4              140          1   1
# 299 0                   395000    1.6              136          1   1
#     time DEATH_EVENT
# 1   4    1
# 2   6    1
# 3   7    1
# ⋮   ⋮    ⋮
# 297 278  0
# 298 280  0
# 299 285  0

# %%
#wrangle the data by selecting the predictors needed and 
#converting the response variable DEATH_EVENT to the factor datatype
data_wrangled <- data |> 
            select(age, high_blood_pressure, ejection_fraction, diabetes, smoking, DEATH_EVENT) |>
            mutate(DEATH_EVENT = as_factor(DEATH_EVENT)) |>
            mutate(DEATH_EVENT = fct_recode(DEATH_EVENT, "Survived" = "0", "Died" = "1")) |>
            mutate(high_blood_pressure = as.logical(high_blood_pressure)) |>
            mutate(diabetes = as.logical(diabetes)) |>
            mutate(smoking = as.logical(smoking))
#rename death event to survive or not and make it so it is true or false
#convert the predicting variables to the logical datatype
data_wrangled

data_nrow <- nrow(data_wrangled)

data_nrow
# Out:
#     age high_blood_pressure ejection_fraction diabetes smoking DEATH_EVENT
# 1   75   TRUE               20                FALSE    FALSE   Died
# 2   55  FALSE               38                FALSE    FALSE   Died
# 3   65  FALSE               20                FALSE     TRUE   Died
# ⋮   ⋮   ⋮                   ⋮                 ⋮        ⋮       ⋮
# 297 45  FALSE               60                 TRUE    FALSE   Survived
# 298 45  FALSE               38                FALSE     TRUE   Survived
# 299 50  FALSE               45                FALSE     TRUE   Survived
# [1] 299

# %%
#set the random seed in R
set.seed(1)

#split the data into training set and testing set
heart_split <- initial_split(data_wrangled, prop = 0.75, strata = DEATH_EVENT)
heart_train <- training(heart_split)
heart_test <- testing(heart_split)

heart_train
heart_test
# Out:
#     age high_blood_pressure ejection_fraction diabetes smoking DEATH_EVENT
# 1   75   TRUE               20                FALSE    FALSE   Died
# 2   55  FALSE               38                FALSE    FALSE   Died
# 3   90   TRUE               40                FALSE     TRUE   Died
# ⋮   ⋮   ⋮                   ⋮                 ⋮        ⋮       ⋮
# 222 62   TRUE               38                 TRUE     TRUE   Survived
# 223 55  FALSE               38                FALSE    FALSE   Survived
# 224 45  FALSE               60                 TRUE    FALSE   Survived
#    age high_blood_pressure ejection_fraction diabetes smoking DEATH_EVENT
# 1  65  FALSE               20                FALSE     TRUE   Died
# 2  50  FALSE               20                FALSE    FALSE   Died
# 3  65  FALSE               20                 TRUE    FALSE   Died
# ⋮  ⋮   ⋮                   ⋮                 ⋮        ⋮       ⋮
# 73 60  FALSE               35                FALSE    FALSE   Survived
# 74 45  FALSE               38                FALSE     TRUE   Survived
# 75 50  FALSE               45                FALSE     TRUE   Survived

# %%
#the number of observations in the training set
train_nrow <- nrow(heart_train)
train_nrow
# Out:
# [1] 224

# %%
#summarize values for subgroups "Survived" and "Died" within the training data set
train_summarize <- heart_train |> 
                   group_by(DEATH_EVENT) |>
                   summarise(count = n())
train_summarize
# Out:
#   DEATH_EVENT count
# 1 Survived    152
# 2 Died         72

# %%
#set our graph to a proper size for visualization
options(repr.plot.width = 8, repr.plot.height = 6)

#visualize the data with a scatter plot
train_graph_point <- heart_train |>
            ggplot(aes(x = age, y = ejection_fraction, color = DEATH_EVENT)) +
            geom_point() + 
            labs(x = "Age", 
                 y = "Percentage of Blood Leaving the Heart at Each Contraction (%)",
                 color = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph_point
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
train_graph <- heart_train |>
            ggplot(aes(x = age, fill = DEATH_EVENT)) +
            geom_histogram() + 
            labs(x = "age",
                 fill = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
train_graph_2 <- heart_train |>
            ggplot(aes(x = ejection_fraction, fill = DEATH_EVENT)) +
            geom_histogram() + 
            labs(x = "Percentage of Blood Leaving the Heart",
                 fill = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph_2
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
#preprocess data to be centered and scaled
#DEATH_EVENT is the response,
#age and ejection_fraction are predictors
heart_recipe <- recipe(DEATH_EVENT ~ age + ejection_fraction, data = heart_train) |>
                step_scale(all_predictors()) |>
                step_center(all_predictors())
heart_recipe
# Out:
# Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          2
#
# Operations:
#
# Scaling for all_predictors()
# Centering for all_predictors()

# %%
#Here we want to do the preparation for finding the best K, so we first apply cross-validation. 
#We split training data to 5 validation set.
heart_vfold <- vfold_cv(heart_train, v = 5, strata = DEATH_EVENT)

knn_tune <- nearest_neighbor(weight_func = "rectangular",
                             neighbors = tune()) |>
            set_engine("kknn") |>
            set_mode("classification")

knn_results <- workflow() |>
                add_recipe(heart_recipe) |>
                add_model(knn_tune) |>
                tune_grid(resamples = heart_vfold, grid = 10) |>
                collect_metrics()
knn_results

# %%
accuracies <- knn_results |>
            filter(.metric == "accuracy")

#visualize the neighbors versus accuracy estimate, therefore, we can find the most optimal K value.
accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) +
                    geom_point() +
                    geom_line() +
                    labs(x = "Neighbors", y = "Accuracy Estimate") +
                    scale_x_continuous(breaks = seq(0, 20, by = 1)) +
                    scale_y_continuous(limits = c(0.4, 1.0))
accuracy_versus_k
# Out:
# plot without title

# %%
#Now that we have explored our data, separated the data into training and testing sets, 
#We applied cross-validation to choose the best k, whcih is 9, so we can now build our final model.

#specification
heart_final_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 9) |>
  set_engine("kknn") |>
  set_mode("classification")

#fit the model
heart_final_fit <- workflow() |>
  add_recipe(heart_recipe) |>
  add_model(heart_final_spec) |>
  fit(heart_train)

# %%
set.seed(1) 
#Use final model to predict on the heart test dataset
heart_failure_predictions <- predict(heart_final_fit, heart_test) |>
        bind_cols(heart_test)

#Report the accuracy of our model
heart_metrics <- heart_failure_predictions |>
        metrics(truth = DEATH_EVENT, estimate = .pred_class)

#Report the confusion matrix
heart_conf_mat <- heart_failure_predictions |>
        conf_mat(truth = DEATH_EVENT, estimate = .pred_class)

heart_failure_predictions
heart_metrics
heart_conf_mat
# Out:
#    .pred_class age high_blood_pressure ejection_fraction diabetes smoking
# 1  Died        65  FALSE               20                FALSE     TRUE
# 2  Died        50  FALSE               20                FALSE    FALSE
# 3  Died        65  FALSE               20                 TRUE    FALSE
# ⋮  ⋮           ⋮   ⋮                   ⋮                 ⋮        ⋮
# 73 Survived    60  FALSE               35                FALSE    FALSE
# 74 Survived    45  FALSE               38                FALSE     TRUE
# 75 Survived    50  FALSE               45                FALSE     TRUE
#    DEATH_EVENT
# 1  Died
# 2  Died
# 3  Died
# ⋮  ⋮
# 73 Survived
# 74 Survived
# 75 Survived
#   .metric  .estimator .estimate
# 1 accuracy binary     0.7466667
# 2 kap      binary     0.3537415
#           Truth
# Prediction Survived Died
#   Survived       46   14
#   Died            5   10

# %% [markdown]
# As the accuracy report shows, our model get about 74.7% correct and fail to predict correctly for 35.4%. Therefore, we can further use more data set to train our model.
