# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
install.packages("kknn")
# Out:
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'”
# Warning message:
# “package ‘kknn’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
data <- read_csv("data/heart_failure_clinical_records_dataset.csv.xls")
data
# Out:
# Rows: 299 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (13): age, anaemia, creatinine_phosphokinase, diabetes, ejection_fractio...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     age anaemia creatinine_phosphokinase diabetes ejection_fraction
# 1   75  0        582                     0        20
# 2   55  0       7861                     0        38
# 3   65  0        146                     0        20
# ⋮   ⋮   ⋮       ⋮                        ⋮        ⋮
# 297 45  0       2060                     1        60
# 298 45  0       2413                     0        38
# 299 50  0        196                     0        45
#     high_blood_pressure platelets serum_creatinine serum_sodium sex smoking
# 1   1                   265000    1.9              130          1   0
# 2   0                   263358    1.1              136          1   0
# 3   0                   162000    1.3              129          1   1
# ⋮   ⋮                   ⋮         ⋮                ⋮            ⋮   ⋮
# 297 0                   742000    0.8              138          0   0
# 298 0                   140000    1.4              140          1   1
# 299 0                   395000    1.6              136          1   1
#     time DEATH_EVENT
# 1   4    1
# 2   6    1
# 3   7    1
# ⋮   ⋮    ⋮
# 297 278  0
# 298 280  0
# 299 285  0

# %%
data_wrangled <- data |> 
            select(age, creatinine_phosphokinase, platelets, ejection_fraction, serum_creatinine, serum_sodium, time, DEATH_EVENT) |>
            mutate(DEATH_EVENT = as_factor(DEATH_EVENT)) |>
            mutate(DEATH_EVENT = fct_recode(DEATH_EVENT, "Deceased" = "1", "Survived" = "0"))
        
data_wrangled
# Out:
#     age creatinine_phosphokinase platelets ejection_fraction serum_creatinine
# 1   75   582                     265000    20                1.9
# 2   55  7861                     263358    38                1.1
# 3   65   146                     162000    20                1.3
# ⋮   ⋮   ⋮                        ⋮         ⋮                 ⋮
# 297 45  2060                     742000    60                0.8
# 298 45  2413                     140000    38                1.4
# 299 50   196                     395000    45                1.6
#     serum_sodium time DEATH_EVENT
# 1   130          4    Deceased
# 2   136          6    Deceased
# 3   129          7    Deceased
# ⋮   ⋮            ⋮    ⋮
# 297 138          278  Survived
# 298 140          280  Survived
# 299 136          285  Survived

# %%
set.seed(1)

heart_split <- initial_split(data_wrangled, prop = 0.75, strata = DEATH_EVENT)
heart_train <- training(heart_split)
heart_test <- testing(heart_split)

heart_train
heart_test
# Out:
#     age creatinine_phosphokinase platelets ejection_fraction serum_creatinine
# 1   75   582                     265000    20                1.9
# 2   55  7861                     263358    38                1.1
# 3   90    47                     204000    40                2.1
# ⋮   ⋮   ⋮                        ⋮         ⋮                 ⋮
# 222 62    61                     155000    38                1.1
# 223 55  1820                     270000    38                1.2
# 224 45  2060                     742000    60                0.8
#     serum_sodium time DEATH_EVENT
# 1   130          4    Deceased
# 2   136          6    Deceased
# 3   132          8    Deceased
# ⋮   ⋮            ⋮    ⋮
# 222 143          270  Survived
# 223 139          271  Survived
# 224 138          278  Survived
#    age creatinine_phosphokinase platelets ejection_fraction serum_creatinine
# 1  65  146                      162000    20                1.3
# 2  50  111                      210000    20                1.9
# 3  65  160                      327000    20                2.7
# ⋮  ⋮   ⋮                        ⋮         ⋮                 ⋮
# 73 60   320                     133000    35                1.4
# 74 45  2413                     140000    38                1.4
# 75 50   196                     395000    45                1.6
#    serum_sodium time DEATH_EVENT
# 1  129          7    Deceased
# 2  137          7    Deceased
# 3  116          8    Deceased
# ⋮  ⋮            ⋮    ⋮
# 73 139          258  Survived
# 74 140          280  Survived
# 75 136          285  Survived

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
train_graph <- heart_train |>
            ggplot(aes(x = age, y = ejection_fraction, color = DEATH_EVENT)) +
            geom_point(alpha = 0.5) + 
            labs(x = "Age",
                 y = "Percentage of Blood Leaving the Heart at Each Contraction (%)",
                 color = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph
# Out:
# plot without title

# %%
heart_recipe <- recipe(DEATH_EVENT ~ age + ejection_fraction, data = heart_train) |>
                step_scale(all_predictors()) |>
                step_center(all_predictors())
heart_recipe
# Out:
# Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          2
#
# Operations:
#
# Scaling for all_predictors()
# Centering for all_predictors()

# %%
heart_vfold <- vfold_cv(heart_train, v = 5, strata = DEATH_EVENT)

knn_tune <- nearest_neighbor(weight_func = "rectangular",
                             neighbors = tune()) |>
            set_engine("kknn") |>
            set_mode("classification")

knn_results <- workflow() |>
                add_recipe(heart_recipe) |>
                add_model(knn_tune) |>
                tune_grid(resamples = heart_vfold, grid = 5) |>
                collect_metrics()
knn_results
# Out:
# Error in `check_installs()`:
# ! Some package installs are required:
# • 'kknn', 'kknn'
# Traceback:
#
# 1. collect_metrics(tune_grid(add_model(add_recipe(workflow(), heart_recipe),
#  .     knn_tune), resamples = heart_vfold, grid = 5))
# 2. tune_grid(add_model(add_recipe(workflow(), heart_recipe), knn_tune),
#  .     resamples = heart_vfold, grid = 5)
# 3. tune_grid.workflow(add_model(add_recipe(workflow(), heart_recipe),
#  .     knn_tune), resamples = heart_vfold, grid = 5)
# 4. tune_grid_workflow(object, resamples = resamples, grid = grid,
#  .     metrics = metrics, pset = param_info, control = control)
# 5. check_workflow(workflow, pset = pset)
# 6. check_installs(hardhat::extract_spec_parsnip(x))
# 7. rlang::abort(c("Some package installs are required: ", paste0("'",
#  .     deps[!is_inst], "'", collapse = ", ")))
# 8. signal_abort(cnd, .file)

# %%
accuracies <- knn_results |>
            filter(.metric == "accuracy")

accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) +
                    geom_point() +
                    geom_line() +
                    labs(x = "Neighbors", y = "Accuracy Estimate") +
                    scale_x_continuous(breaks = seq(0, 14, by = 1)) +
                    scale_y_continuous(limits = c(0.4, 1.0))
accuracy_versus_k
