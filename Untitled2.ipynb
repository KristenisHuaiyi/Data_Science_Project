# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
install.packages("kknn")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.2     ✔ rsample      1.1.1
# ✔ dials        1.1.0     ✔ tune         1.0.1
# ✔ infer        1.0.4     ✔ workflows    1.1.2
# ✔ modeldata    1.0.1     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.3     ✔ yardstick    1.1.0
# ✔ recipes      1.0.4
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
data <- read_csv("data/heart_failure_clinical_records_dataset.csv.xls")
data
# Out:
# Rows: 299 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (13): age, anaemia, creatinine_phosphokinase, diabetes, ejection_fractio...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     age anaemia creatinine_phosphokinase diabetes ejection_fraction
# 1   75  0        582                     0        20
# 2   55  0       7861                     0        38
# 3   65  0        146                     0        20
# ⋮   ⋮   ⋮       ⋮                        ⋮        ⋮
# 297 45  0       2060                     1        60
# 298 45  0       2413                     0        38
# 299 50  0        196                     0        45
#     high_blood_pressure platelets serum_creatinine serum_sodium sex smoking
# 1   1                   265000    1.9              130          1   0
# 2   0                   263358    1.1              136          1   0
# 3   0                   162000    1.3              129          1   1
# ⋮   ⋮                   ⋮         ⋮                ⋮            ⋮   ⋮
# 297 0                   742000    0.8              138          0   0
# 298 0                   140000    1.4              140          1   1
# 299 0                   395000    1.6              136          1   1
#     time DEATH_EVENT
# 1   4    1
# 2   6    1
# 3   7    1
# ⋮   ⋮    ⋮
# 297 278  0
# 298 280  0
# 299 285  0

# %%
data_wrangled <- data |> 
            select(age, high_blood_pressure, ejection_fraction, diabetes, smoking, DEATH_EVENT) |>
            mutate(DEATH_EVENT = as_factor(DEATH_EVENT)) |>
            mutate(DEATH_EVENT = fct_recode(DEATH_EVENT, "Survived" = "1", "Died" = "0")) |>
            mutate(high_blood_pressure = as.logical(high_blood_pressure)) |>
            mutate(diabetes = as.logical(diabetes)) |>
            mutate(smoking = as.logical(smoking))
#rename death event to survive or not and make it so it is true or false 
data_wrangled

data_nrow <- nrow(data_wrangled)

data_nrow
# Out:
#     age high_blood_pressure ejection_fraction diabetes smoking DEATH_EVENT
# 1   75   TRUE               20                FALSE    FALSE   Survived
# 2   55  FALSE               38                FALSE    FALSE   Survived
# 3   65  FALSE               20                FALSE     TRUE   Survived
# ⋮   ⋮   ⋮                   ⋮                 ⋮        ⋮       ⋮
# 297 45  FALSE               60                 TRUE    FALSE   Died
# 298 45  FALSE               38                FALSE     TRUE   Died
# 299 50  FALSE               45                FALSE     TRUE   Died
# [1] 299

# %%
set.seed(1)

heart_split <- initial_split(data_wrangled, prop = 0.75, strata = DEATH_EVENT)
heart_train <- training(heart_split)
heart_test <- testing(heart_split)

heart_train
heart_test
# Out:
#     age creatinine_phosphokinase platelets ejection_fraction serum_creatinine
# 1   49  80                       427000    30                1.0
# 2   65  52                       276000    25                1.3
# 3   70  75                       223000    35                2.7
# ⋮   ⋮   ⋮                        ⋮         ⋮                 ⋮
# 222 55  2017                     314000    25                1.10
# 223 65   258                     198000    25                1.40
# 224 55  1199                     263358    20                1.83
#     serum_sodium time DEATH_EVENT
# 1   138          12   Died
# 2   137          16   Died
# 3   138          54   Died
# ⋮   ⋮            ⋮    ⋮
# 222 138          214  Survived
# 223 129          235  Survived
# 224 134          241  Survived
#    age creatinine_phosphokinase platelets ejection_fraction serum_creatinine
# 1  75   81                      368000    38                4.0
# 2  70  125                      237000    25                1.0
# 3  53   63                      368000    60                0.8
# ⋮  ⋮   ⋮                        ⋮         ⋮                 ⋮
# 73 90  337                      390000    38                0.9
# 74 45  615                      222000    55                0.8
# 75 50  196                      395000    45                1.6
#    serum_sodium time DEATH_EVENT
# 1  131          10   Survived
# 2  140          15   Survived
# 3  135          22   Died
# ⋮  ⋮            ⋮    ⋮
# 73 144          256  Died
# 74 141          257  Died
# 75 136          285  Died

# %%
train_nrow <- nrow(heart_train)
train_nrow
# Out:
# [1] 224

# %%
train_summarize <- heart_train |> 
                   group_by(DEATH_EVENT) |>
                   summarise(count = n())
train_summarize
# Out:
#   DEATH_EVENT count
# 1 Died        152
# 2 Survived     72

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
train_graph_point <- heart_train |>
            ggplot(aes(x = age, y = ejection_fraction, color = DEATH_EVENT)) +
            geom_point() + 
            labs(x = "Age", 
                 y = "Percentage of Blood Leaving the Heart at Each Contraction (%)",
                 color = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph_point
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
train_graph <- heart_train |>
            ggplot(aes(x = age, fill = DEATH_EVENT)) +
            geom_histogram() + 
            labs(x = "age",
                 fill = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
train_graph_2 <- heart_train |>
            ggplot(aes(x = platelets, fill = DEATH_EVENT)) +
            geom_histogram() + 
            labs(x = "Platelets in Blood (kiloplatelets/mL)",
                 fill = "Survived/Deceased?") +
            theme(text = element_text(size = 14))
train_graph_2
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
heart_recipe <- recipe(DEATH_EVENT ~ age + ejection_fraction, data = heart_train) |>
                step_scale(all_predictors()) |>
                step_center(all_predictors())
heart_recipe
# Out:
# Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          2
#
# Operations:
#
# Scaling for all_predictors()
# Centering for all_predictors()

# %%
heart_vfold <- vfold_cv(heart_train, v = 5, strata = DEATH_EVENT)

knn_tune <- nearest_neighbor(weight_func = "rectangular",
                             neighbors = tune()) |>
            set_engine("kknn") |>
            set_mode("classification")

knn_results <- workflow() |>
                add_recipe(heart_recipe) |>
                add_model(knn_tune) |>
                tune_grid(resamples = heart_vfold, grid = 5) |>
                collect_metrics()
knn_results
# Out:
#   neighbors .metric  .estimator mean      n std_err    .config
# 1 3         accuracy binary     0.7098814 5 0.01913427 Preprocessor1_Model1
# 2 3         roc_auc  binary     0.7304531 5 0.03953023 Preprocessor1_Model1
# 3 5         accuracy binary     0.7274704 5 0.01178088 Preprocessor1_Model2
# ⋮ ⋮         ⋮        ⋮          ⋮         ⋮ ⋮          ⋮
# 6  9        roc_auc  binary     0.7709140 5 0.03686067 Preprocessor1_Model3
# 7 13        accuracy binary     0.7454545 5 0.01165254 Preprocessor1_Model4
# 8 13        roc_auc  binary     0.7590323 5 0.03720140 Preprocessor1_Model4

# %%
accuracies <- knn_results |>
            filter(.metric == "accuracy")

accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) +
                    geom_point() +
                    geom_line() +
                    labs(x = "Neighbors", y = "Accuracy Estimate") +
                    scale_x_continuous(breaks = seq(0, 14, by = 1)) +
                    scale_y_continuous(limits = c(0.4, 1.0))
accuracy_versus_k
# Out:
# plot without title
